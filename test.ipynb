# %%
import requests  # API calls
import json      # JSON handling
import time      # For retry backoff
import logging   # Structured logging
from typing import Optional, Dict, Any, List  # Type hints for clarity
from copy import deepcopy


# Setup logging

logging.basicConfig(
    level=logging.INFO,
    format="%(asctime)s [%(levelname)s] %(message)s",
    handlers=[
        logging.StreamHandler(),
        logging.FileHandler("pipeline.log")
    ]
)


# API ingestion class

class APIIngestor:
    def __init__(self, base_url: str, max_retries: int = 5, backoff_factor: float = 0.5):
        """
        Initialize the API ingestor.

        Args:
            base_url (str): Base URL of the API.
            max_retries (int): Number of retries for failed requests.
            backoff_factor (float): Backoff multiplier for retries.
        """
        self.base_url = base_url
        self.max_retries = max_retries
        self.backoff_factor = backoff_factor

    def _make_request(self, url: str, params: Optional[Dict[str, Any]] = None) -> Dict:
        """
        Make a GET request with retry logic.

        Args:
            url (str): Full API endpoint URL.
            params (dict, optional): Query parameters.

        Returns:
            dict: Parsed JSON response.
        """
        retries = 0
        while retries < self.max_retries:
            try:
                response = requests.get(url, params=params, timeout=10)
                if response.status_code == 200:
                    return response.json()
                else:
                    logging.warning(f"Request failed [{response.status_code}]: {response.text}")
            except requests.RequestException as e:
                logging.warning(f"Request exception: {e}")

            retries += 1
            sleep_time = self.backoff_factor * (2 ** (retries - 1))
            logging.info(f"Retrying in {sleep_time:.1f}s...")
            time.sleep(sleep_time)

        raise Exception(f"Failed to fetch data from {url} after {self.max_retries} retries")

    #fetch_paginated → “I want all users, but I can only carry 100 at a time.”



    def fetch_paginated(
            self,
            endpoint: str,
            params: Optional[Dict[str, Any]] = None,
            page_param: str = "page",
            per_page: int = 100,
            max_pages: Optional[int] = None,
            months: Optional[List[str]] = None  # NEW: optional list of months
        ) -> List[Dict]:
        """
        Fetch data from APIs that paginate results.

        Args:
            endpoint (str): API endpoint path.
            params (dict, optional): Query parameters.
            page_param (str): Parameter name for page number.
            per_page (int): Number of results per page.
            max_pages (int, optional): Maximum number of pages to fetch.
            months (list of str, optional): List of months to fetch (e.g., ["2025-01", "2025-02"]).

        Returns:
            List[Dict]: List of all records fetched.
        """
        results = []

        # If no months are provided, default to single month in params
        if months is None:
            months = [params.get("date")] if params and "date" in params else [None]

        for month in months:
            page = 1
            while True:
                paged_params = deepcopy(params) if params else {}
                if month:
                    paged_params["date"] = month
                paged_params.update({page_param: page, "results": per_page})

                logging.info(f"Fetching page {page} from {endpoint} for month {month}")
                data = self._make_request(f"{self.base_url}{endpoint}", paged_params)

                # Support APIs that return either a list or a dict with 'results'
                items = data.get("results") if isinstance(data, dict) and "results" in data else data
                if not items:
                    break

                results.extend(items)

                if max_pages and page >= max_pages:
                    break
                if len(items) < per_page:
                    break

                page += 1

        return results

        

    #fetch_incremental → “I want only the users added or updated since yesterday.”

    def fetch_incremental(
        self,
        endpoint: str,
        since: Optional[str] = None,
        params: Optional[Dict[str, Any]] = None
    ) -> List[Dict]:
        """
        Fetch only new or updated records since a given timestamp or ID.

        Args:
            endpoint (str): API endpoint path.
            since (str, optional): Timestamp or ID to fetch incremental data from.
            params (dict, optional): Additional query parameters.

        Returns:
            List[Dict]: Incremental data.
        """
        query_params = params.copy() if params else {}
        if since:
            query_params["since"] = since

        logging.info(f"Fetching incremental data from {endpoint} since {since}")
        data = self._make_request(f"{self.base_url}{endpoint}", query_params)
        return data.get("results") if isinstance(data, dict) and "results" in data else data

    def batch_process(self, data: List[Dict], batch_size: int = 50):
        """
        Yield data in batches.

        Args:
            data (List[Dict]): List of records.
            batch_size (int): Size of each batch.

        Yields:
            List[Dict]: Batch of records.
        """
        for i in range(0, len(data), batch_size):
            yield data[i:i + batch_size]



##Instantiting the Class
if __name__ == "__main__":                       #This line ensures the code only runs when the script is executed directly, not when imported as a module in another script.
   
    ingestor = APIIngestor(base_url="https://data.police.uk/api/")

    # Example: Fetch multiple pages from Police UK API
    all_crimes = ingestor.fetch_paginated(
        endpoint="/api/crimes-street/all-crime",
        params = {
            "date": f"2025-{month:02d}",
        "lat": 52.629729,
        "lng": -1.131592},
            per_page=200,
            max_pages=20
    )
    logging.info(f"Total users fetched: {len(all_crimes)}")

    # Process in batches
    for batch in ingestor.batch_process(all_crimes, batch_size=100):
        logging.info(f"Processing batch of {len(batch)} crimes")
        logging.info(f"Batch type: {type(batch)} | Sample: {batch[:2] if isinstance(batch, list) else batch}")
        logging.info(batch[1]["location"]["street"]["name"])



#Light Transformation
# Out:
# 2025-10-31 21:51:16,935 [INFO] Fetching page 1 from /api/crimes-street/all-crime for month None
# 2025-10-31 21:51:17,193 [INFO] Fetching page 2 from /api/crimes-street/all-crime for month None
# 2025-10-31 21:51:17,324 [INFO] Fetching page 3 from /api/crimes-street/all-crime for month None
# 2025-10-31 21:51:17,713 [INFO] Fetching page 4 from /api/crimes-street/all-crime for month None
# 2025-10-31 21:51:18,194 [INFO] Fetching page 5 from /api/crimes-street/all-crime for month None
# 2025-10-31 21:51:18,315 [INFO] Fetching page 6 from /api/crimes-street/all-crime for month None
# 2025-10-31 21:51:18,692 [INFO] Fetching page 7 from /api/crimes-street/all-crime for month None
# 2025-10-31 21:51:19,205 [INFO] Fetching page 8 from /api/crimes-street/all-crime for month None
# 2025-10-31 21:51:19,695 [INFO] Fetching page 9 from /api/crimes-street/all-crime for month None
# 2025-10-31 21:51:20,191 [INFO] Fetching page 10 from /api/crimes-street/all-crime for month None
# 2025-10-31 21:51:20,692 [INFO] Fetching page 11 from /api/crimes-street/all-crime for month None
# 2025-10-31 21:51:21,211 [INFO] Fetching page 12 from /api/crimes-street/all-crime for month None
# 2025-10-31 21:51:21,329 [INFO] Fetching page 13 from /api/crimes-street/all-crime for month None
# 2025-10-31 21:51:21,832 [INFO] Fetching page 14 from /api/crimes-street/all-crime for month None
# 2025-10-31 21:51:21,949 [INFO] Fetching page 15 from /api/crimes-street/all-crime for month None
# 2025-10-31 21:51:22,337 [INFO] Fetching page 16 from /api/crimes-street/all-crime for month None
# 2025-10-31 21:51:22,456 [INFO] Fetching page 17 from /api/crimes-street/all-crime for month None
# 2025-10-31 21:51:22,951 [INFO] Fetching page 18 from /api/crimes-street/all-crime for month None
# 2025-10-31 21:51:23,450 [INFO] Fetching page 19 from /api/crimes-street/all-crime for month None
# 2025-10-31 21:51:23,953 [INFO] Fetching page 20 from /api/crimes-street/all-crime for month None
# 2025-10-31 21:51:24,447 [INFO] Total users fetched: 34860
# 2025-10-31 21:51:24,448 [INFO] Processing batch of 100 crimes
# 2025-10-31 21:51:24,448 [INFO] Batch type: <class 'list'> | Sample: [{'category': 'anti-social-behaviour', 'location_type': 'Force', 'location': {'latitude': '52.618023', 'street': {'id': 1738421, 'name': 'On or near Putney Road'}, 'longitude': '-1.129457'}, 'context': '', 'outcome_status': None, 'persistent_id': '', 'id': 130958025, 'location_subtype': '', 'month': '2025-08'}, {'category': 'anti-social-behaviour', 'location_type': 'Force', 'location': {'latitude': '52.636211', 'street': {'id': 1738740, 'name': 'On or near Wimbledon Street'}, 'longitude': '-1.125919'}, 'context': '', 'outcome_status': None, 'persistent_id': '', 'id': 130958035, 'location_subtype': '', 'month': '2025-08'}]
# 2025-10-31 21:51:24,449 [INFO] On or near Wimbledon Street
# 2025-10-31 21:51:24,449 [INFO] Processing batch of 100 crimes
# 2025-10-31 21:51:24,449 [INFO] Batch type: <class 'list'> | Sample: [{'category': 'anti-social-behaviour', 'location_type': 'Force', 'location': {'latitude': '52.629880', 'street': {'id': 1738479, 'name': 'On or near Princess Road Backways'}, 'longitude': '-1.130492'}, 'context': '', 'outcome_status': None, 'persistent_id': '', 'id': 130957623, 'location_subtype': '', 'month': '2025-08'}, {'category': 'anti-social-behaviour', 'location_type': 'Force', 'location': {'latitude': '52.636041', 'street': {'id': 1738351, 'name': 'On or near East Gates'}, 'longitude': '-1.133444'}, 'context': '', 'outcome_status': None, 'persistent_id': '', 'id': 130957634, 'location_subtype': '', 'month': '2025-08'}]
# 2025-10-31 21:51:24,450 [INFO] On or near East Gates
# 2025-10-31 21:51:24,450 [INFO] Processing batch of 100 crimes
# 2025-10-31 21:51:24,450 [INFO] Batch type: <class 'list'> | Sample: [{'category': 'anti-social-behaviour', 'location_type': 'Force', 'location': {'latitude': '52.634503', 'street': {'id': 1737385, 'name': 'On or near Kate Street'}, 'longitude': '-1.149403'}, 'context': '', 'outcome_status': None, 'persistent_id': '', 'id': 130958802, 'location_subtype': '', 'month': '2025-08'}, {'category': 'anti-social-behaviour', 'location_type': 'Force', 'location': {'latitude': '52
 'location_subtype': '', 'month': '2025-08'}]
# 2025-10-31 21:51:24,776 [INFO] On or near Euston Street
# 2025-10-31 21:51:24,777 [INFO] Processing batch of 100 crimes
# 2025-10-31 21:51:24,777 [INFO] Batch type: <class 'list'> | Sample: [{'category': 'other-theft', 'location_type': 'Force', 'location': {'latitude': '52.640498', 'street': {'id': 1737983, 'name': "On or near St Margaret's Street"}, 'longitude': '-1.136799'}, 'context': '', 'outcome_status': {'category': 'Under investigation', 'date': '2025-08'}, 'persistent_id': '7c44a294e2bdea5fbd99afac448a78f474e8f46a6689400ffd00bca5709e0fd8', 'id': 130893272, 'location_subtype': '', 'month': '2025-08'}, {'category': 'other-theft', 'location_type': 'Force', 'location': {'latitude': '52.638882', 'street': {'id': 1738334, 'name': 'On or near Sandacre Street'}, 'longitude': '-1.133417'}, 'context': '', 'outcome_status': {'category': 'Investigation complete; no suspect identified', 'date': '2025-08'}, 'persistent_id': '9fd1548ee5c6900b7b0ffae8463fa79f21cc4aae1026468b275eccc63f0985c1', 'id': 130953837, 'location_subtype': '', 'month': '2025-08'}]
# 2025-10-31 21:51:24,777 [INFO] On or near Sandacre Street
# 2025-10-31 21:51:24,777 [INFO] Processing batch of 100 crimes
# 2025-10-31 21:51:24,778 [INFO] Batch type: <class 'list'> | Sample: [{'category': 'public-order', 'location_type': 'Force', 'location': {'latitude': '52.635797', 'street': {'id': 1738449, 'name': 'On or near Fox Lane'}, 'longitude': '-1.131926'}, 'context': '', 'outcome_status': {'category': 'Investigation complete; no suspect identified', 'date': '2025-08'}, 'persistent_id': '9e589215a167c6fcd0498bb34a374c7d212558847cca64cb0b40b4bf19335d61', 'id': 130949582, 'location_subtype': '', 'month': '2025-08'}, {'category': 'public-order', 'location_type': 'Force', 'location': {'latitude': '52.632778', 'street': {'id': 1737719, 'name': 'On or near Westbridge Close'}, 'longitude': '-1.143349'}, 'context': '', 'outcome_status': {'category': 'Investigation complete; no suspect identified', 'date': '2025-08'}, 'persistent_id': '70af5ba6bf9033d82282a8819ae28a9c5866fa2950fa9eebded2983b479609f8', 'id': 130951636, 'location_subtype': '', 'month': '2025-08'}]
# 2025-10-31 21:51:24,778 [INFO] On or near Westbridge Close
# 2025-10-31 21:51:24,778 [INFO] Processing batch of 100 crimes
# 2025-10-31 21:51:24,778 [INFO] Batch type: <class 'list'> | Sample: [{'category': 'public-order', 'location_type': 'Force', 'location': {'latitude': '52.625975', 'street': {'id': 1738088, 'name': 'On or near Farndale Close'}, 'longitude': '-1.137410'}, 'context': '', 'outcome_status': {'category': 'Under investigation', 'date': '2025-08'}, 'persistent_id': 'e36cac46f1050ccb2ff6465e405674255ec78aa7ea6adc8862b064ececc4b5b1', 'id': 130954268, 'location_subtype': '', 'month': '2025-08'}, {'category': 'public-order', 'location_type': 'Force', 'location': {'latitude': '52.626782', 'street': {'id': 1738090, 'name': 'On or near Hospital'}, 'longitude': '-1.135961'}, 'context': '', 'outcome_status': {'category': 'Further investigation is not in the public interest', 'date': '2025-08'}, 'persistent_id': '2b783d0269a2b4c3e355f8cb74512a2c68f2168f379a19c2f35d2ad561391d26', 'id': 130953375, 'location_subtype': '', 'month': '2025-08'}]
# 2025-10-31 21:51:24,779 [INFO] On or near Hospital
# 2025-10-31 21:51:24,779 [INFO] Processing batch of 100 crimes
# 2025-10-31 21:51:24,779 [INFO] Batch type: <class 'list'> | Sample: [{'category': 'shoplifting', 'location_type': 'Force', 'location': {'latitude': '52.628717', 'street': {'id': 1737809, 'name': 'On or near Mill Lane'}, 'longitude': '-1.142394'}, 'context': '', 'outcome_status': {'category': 'Investigation complete; no suspect identified', 'date': '2025-08'}, 'persistent_id': '4fdf9cd21ca4e38caa3ec8e79fc8c9c86306a0987416cbe86e47d2de7610be62', 'id': 130955498, 'location_subtype': '', 'month': '2025-08'}, {'category': 'shoplifting', 'location_type': 'Force', 'location': {'latitude': '52.636723', 'street': {'id': 1738235, 'name': 'On or near New Bond Street'}, 'longitude': '-1.134450'}, 'context': '', 'outcome_status': {'category': 'Awaiting court outcome', 'date': '2025-08'}, 'persistent_id': '880d2ee354e2600310734a607d57c34f014e621b9c4fbe16ee827ee13e8070ff', 'id': 130952056, 'location_subtype': '', 'month': '2025-08'}]
# 2025-10-31 21:51:24,779 [INFO] On or near New Bond Street
# 2025-10-31 21:51:24,779 [INFO] Processing batch of 100 crimes
# 2025-10-31 21:51:24,780 [INFO] Batch type: <class 'list'> | Sample: [{'category': 'shoplifting', 'location_type': 'Force', 'location': {'latitude': '52.636060', 'street': {'id': 1738987, 'name': 'On or near Supermarket'}, 'longitude': '-1.120153'}, 'context': '', 'outcome_status': {'category': 'Investigation complete; no suspect identified', 'date': '2025-08'}, 'persistent_id': '6f8e1c6874d84a13b1a72b09b51edf306ed1cea10cc1aadbd8f14a8e6b3a7ec6', 'id': 130951516, 'location_subtype': '', 'month': '2025-08'}, {'category': 'shoplifting', 'location_type': 'Force', 'location': {'latitude': '52.636041', 'street': {'id': 1738351, 'name': 'On or near East Gates'}, 'longitude': '-1.133444'}, 'context': '', 'outcome_status': {'category': 'Under investigation', 'date': '2025-08'}, 'persistent_id': 'ed7ae3ac27c6cc16f41b239ef856451099d4778bccfb7e5ce02e22f996265364', 'id': 130951522, 'location_subtype': '', 'month': '2025-08'}]
# 2025-10-31 21:51:24,780 [INFO] On or near East Gates
# 2025-10-31 21:51:24,780 [INFO] Processing batch of 100 crimes
# 2025-10-31 21:51:24,780 [INFO] Batch type: <class 'list'> | Sample: [{'category': 'vehicle-crime', 'location_type': 'Force', 'location': {'latitude': '52.642024', 'street': {'id': 1737685, 'name': 'On or near North Bridge Place'}, 'longitude': '-1.143892'}, 'context': '', 'outcome_status': {'category': 'Investigation complete; no suspect identified', 'date': '2025-08'}, 'persistent_id': '4aa910085861f834bd5b1599fe8710c22c9d72454dff9cb024eb2098316f2313', 'id': 130955084, 'location_subtype': '', 'month': '2025-08'}, {'category': 'vehicle-crime', 'location_type': 'Force', 'location': {'latitude': '52.633317', 'street': {'id': 1738721, 'name': 'On or near Church Street'}, 'longitude': '-1.127203'}, 'context': '', 'outcome_status': {'category': 'Under investigation', 'date': '2025-08'}, 'persistent_id': 'a92bb5a3a683fa542e03e24313a97b58867e272f650a7b185c72b6c16e1a6eb1', 'id': 130950246, 'location_subtype': '', 'month': '2025-08'}]
# 2025-10-31 21:51:24,781 [INFO] On or near Church Street
# 2025-10-31 21:51:24,781 [INFO] Processing batch of 100 crimes
# 2025-10-31 21:51:24,781 [INFO] Batch type: <class 'list'> | Sample: [{'category': 'vehicle-crime', 'location_type': 'Force', 'location': {'latitude': '52.628473', 'street': {'id': 1737234, 'name': 'On or near Harrow Road'}, 'longitude': '-1.153553'}, 'context': '', 'outcome_status': {'category': 'Investigation complete; no suspect identified', 'date': '2025-08'}, 'persistent_id': 'cef7ac18acf80430e93c449d4bb7f96206370d6a98b894aa261daace6275370d', 'id': 130954979, 'location_subtype': '', 'month': '2025-08'}, {'category': 'vehicle-crime', 'location_type': 'Force', 'location': {'latitude': '52.626898', 'street': {'id': 1739308, 'name': 'On or near Onslow Street'}, 'longitude': '-1.113960'}, 'context': '', 'outcome_status': {'category': 'Investigation complete; no suspect identified', 'date': '2025-08'}, 'persistent_id': 'f8ee6e501c0ced77281586f4214c1dd41c91f692ae4149c8805dcd05794ac803', 'id': 130951151, 'location_subtype': '', 'month': '2025-08'}]
# 2025-10-31 21:51:24,781 [INFO] On or near Onslow Street
# 2025-10-31 21:51:24,782 [INFO] Processing batch of 100 crimes
# 2025-10-31 21:51:24,782 [INFO] Batch type: <class 'list'> | Sample: [{'category': 'violent-crime', 'location_type': 'Force', 'location': {'latitude': '52.635528', 'street': {'id': 1738700, 'name': 'On or near Theatre/concert Hall'}, 'longitude': '-1.127553'}, 'context': '', 'outcome_status': {'category': 'Unable to prosecute suspect', 'date': '2025-08'}, 'persistent_id': 'e17ffe8af154cb8bf31c9ca4cdcd373553d393b331bf6614bb56b872c1d30133', 'id': 130949709, 'location_subtype': '', 'month': '2025-08'}, {'category': 'violent-crime', 'location_type': 'Force', 'location': {'latitude': '52.639764', 'street': {'id': 1738451, 'name': 'On or near Abbey Street'}, 'longitude': '-1.132277'}, 'context': '', 'outcome_status': {'category': 'Local resolution', 'date': '2025-08'}, 'persistent_id': 'b045d98390a8b6bb842720e175b0b382128606372f49a66bfde76098ce1d1b6f', 'id': 130949708, 'location_subtype': '', 'month': '2025-08'}]
# 2025-10-31 21:51:24,782 [INFO] On or near Abbey Street
# 2025-10-31 21:51:24,782 [INFO] Processing batch of 100 crimes
# 2025-10-31 21:51:24,782 [INFO] Batch type: <class 'list'> | Sample: [{'category': 'violent-crime', 'location_type': 'Force', 'location': {'latitude': '52.616105', 'street': {'id': 1738350, 'name': 'On or near Euston Street'}, 'longitude': '-1.132611'}, 'context': '', 'outcome_status': {'category': 'Under investigation', 'date': '2025-08'}, 'persistent_id': '6b6ca6f3bdb8da8123ba4c896591a5503ae49a04a2673dc40ed51d29b589a3d2', 'id': 130957209, 'location_subtype': '', 'month': '2025-08'}, {'category': 'violent-crime', 'location_type': 'Force', 'location': {'latitude': '52.626576', 'street': {'id': 1737515, 'name': 'On or near Paton Street'}, 'longitude': '-1.148404'}, 'context': '', 'outcome_status': {'category': 'Under investigation', 'date': '2025-08'}, 'persistent_id': '4ae0de9cd5e7ca5a614a3b106982c46db0f4bec40c41d9ba5bba1d1193d48740', 'id': 130957199, 'location_subtype': '', 'month': '2025-08'}]
# 2025-10-31 21:51:24,783 [INFO] On or near Paton Street
# 2025-10-31 21:51:24,783 [INFO] Processing batch of 100 crimes
# 2025-10-31 21:51:24,783 [INFO] Batch type: <class 'list'> | Sample: [{'category': 'violent-crime', 'location_type': 'Force', 'location': {'latitude': '52.628379', 'street': {'id': 1739269, 'name': 'On or near Medway Street'}, 'longitude': '-1.114832'}, 'context': '', 'outcome_status': {'category': 'Under investigation', 'date': '2025-08'}, 'persistent_id': 'c7fd439908cf2fadf4044771c60f7323df53d4723b8836bc373f75842c4d5a1c', 'id': 130952281, 'location_subtype': '', 'month': '2025-08'}, {'category': 'violent-crime', 'location_type': 'Force', 'location': {'latitude': '52.635488', 'street': {'id': 1738121, 'name': 'On or near Carts Lane'}, 'longitude': '-1.136395'}, 'context': '', 'outcome_status': {'category': 'Under investigation', 'date': '2025-08'}, 'persistent_id': 'c3f4f62763b5e6f70339e9b4b0ebd9f8dcc41477c65270a19f09b9e061d3521d', 'id': 130952283, 'location_subtype': '', 'month': '2025-08'}]
# 2025-10-31 21:51:24,783 [INFO] On or near Carts Lane
# 2025-10-31 21:51:24,783 [INFO] Processing batch of 100 crimes
# 2025-10-31 21:51:24,784 [INFO] Batch type: <class 'list'> | Sample: [{'category': 'violent-crime', 'location_type': 'Force', 'location': {'latitude': '52.636060', 'street': {'id': 1738987, 'name': 'On or near Supermarket'}, 'longitude': '-1.120153'}, 'context': '', 'outcome_status': {'category': 'Investigation complete; no suspect identified', 'date': '2025-08'}, 'persistent_id': '02967944e422b8378c9eaea4c05c49668f1c35e57eb22bd12d16972864a24722', 'id': 130950048, 'location_subtype': '', 'month': '2025-08'}, {'category': 'violent-crime', 'location_type': 'Force', 'location': {'latitude': '52.628111', 'street': {'id': 1737188, 'name': 'On or near Barclay Street'}, 'longitude': '-1.154417'}, 'context': '', 'outcome_status': {'category': 'Unable to prosecute suspect', 'date': '2025-08'}, 'persistent_id': '2cdf3d83ae5622d422e472366584b6a3854facdc6ccf2def981dc560f23913f3', 'id': 130950165, 'location_subtype': '', 'month': '2025-08'}]
# 2025-10-31 21:51:24,784 [INFO] On or near Barclay Street
# 2025-10-31 21:51:24,784 [INFO] Processing batch of 60 crimes
# 2025-10-31 21:51:24,784 [INFO] Batch type: <class 'list'> | Sample: [{'category': 'violent-crime', 'location_type': 'Force', 'location': {'latitude': '52.625937', 'street': {'id': 1739392, 'name': 'On or near Tennyson Street'}, 'longitude': '-1.112783'}, 'context': '', 'outcome_status': {'category': 'Unable to prosecute suspect', 'date': '2025-08'}, 'persistent_id': '90aa05d06a58b2e415d4ea032e68f4f6fb7df27634fb9cf3f46cae5e38312fea', 'id': 130955155, 'location_subtype': '', 'month': '2025-08'}, {'category': 'violent-crime', 'location_type': 'Force', 'location': {'latitude': '52.627052', 'street': {'id': 1737887, 'name': 'On or near Ullswater Street'}, 'longitude': '-1.140875'}, 'context': '', 'outcome_status': {'category': 'Unable to prosecute suspect', 'date': '2025-08'}, 'persistent_id': '8c09830c62138ef3ce977c5cfe769ca2e9c8443716b772c95dc4a85153933bdc', 'id': 130949688, 'location_subtype': '', 'month': '2025-08'}]
# 2025-10-31 21:51:24,785 [INFO] On or near Ullswater Street

# %%
import requests

url = "https://data.police.uk/api/crimes-street/all-crime"
params = {
    "date": "2024-01",
    "lat": 52.629729,
    "lng": -1.131592
}

response = requests.get(url, params=params)

if response.status_code == 200:
    data = response.json()
    print(f"Returned {len(data)} records")
    print(data[0])  # sample record
else:
    print(f"Error: {response.status_code}")
# Out:
# Returned 1472 records
# {'category': 'anti-social-behaviour', 'location_type': 'Force', 'location': {'latitude': '52.639558', 'street': {'id': 1738364, 'name': 'On or near Nightclub'}, 'longitude': '-1.132473'}, 'context': '', 'outcome_status': None, 'persistent_id': '', 'id': 116208928, 'location_subtype': '', 'month': '2024-01'}

# %%
import pandas as pd

# Convert the raw list of crime dictionaries to a flattened DataFrame
df = pd.json_normalize(all_crimes)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34860 entries, 0 to 34859
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   category                 34860 non-null  object
#  1   location_type            34860 non-null  object
#  2   context                  34860 non-null  object
#  3   outcome_status           0 non-null      float64
#  4   persistent_id            34860 non-null  object
#  5   id                       34860 non-null  int64
#  6   location_subtype         34860 non-null  object
#  7   month                    34860 non-null  object
#  8   location.latitude        34860 non-null  object
#  9   location.street.id       34860 non-null  int64
#  10  location.street.name     34860 non-null  object
#  11  location.longitude       34860 non-null  object
#  12  outcome_status.category  30220 non-null  object
#  13  outcome_status.date      30220 non-null  object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 3.7+ MB

# %%
# Replace NaN in all columns with 'unknown'
columns_to_drop = ['outcome_status']
df = (
    df.drop(columns=columns_to_drop).rename(columns={
    'location.street.name': 'street_name',
    'location.latitude': 'latitude',
    'location.longitude': 'longitude',
    'outcome_status.category': 'outcome_status_category',
     'outcome_status.date': 'outcome_status_date'  
})
)
df.head()
# Out:
#                 category location_type context persistent_id         id  \
# 0  anti-social-behaviour         Force                        130066740
# 1  anti-social-behaviour         Force                        130066726
# 2  anti-social-behaviour         Force                        130066724
# 3  anti-social-behaviour         Force                        130067358
# 4  anti-social-behaviour         Force                        130067331
#
#   location_subtype    month   latitude  location.street.id  \
# 0                   2025-07  52.621857             1737629
# 1                   2025-07  52.627798             1737705
# 2                   2025-07  52.627798             1737705
# 3                   2025-07  52.628462             1738792
# 4                   2025-07  52.636041             1738351
#
#                      street_name  longitude outcome_status_category  \
# 0       On or near Quainton Road  -1.146029                 unknown
# 1       On or near Tarragon Road  -1.144613                 unknown
# 2       On or near Tarragon Road  -1.144613                 unknown
# 3  On or near De Montfort Square  -1.126029                 unknown
# 4          On or near East Gates  -1.133444                 unknown
#
#   outcome_status_date
# 0             unknown
# 1             unknown
# 2             unknown
# 3             unknown
# 4             unknown

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17240 entries, 0 to 17239
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   category                 17240 non-null  object
#  1   location_type            17240 non-null  object
#  2   context                  17240 non-null  object
#  3   persistent_id            17240 non-null  object
#  4   id                       17240 non-null  int64
#  5   location_subtype         17240 non-null  object
#  6   month                    17240 non-null  object
#  7   latitude                 17240 non-null  object
#  8   location.street.id       17240 non-null  int64
#  9   street_name              17240 non-null  object
#  10  longitude                17240 non-null  object
#  11  outcome_status_category  17240 non-null  object
#  12  outcome_status_date      17240 non-null  object
# dtypes: int64(2), object(11)
# memory usage: 1.7+ MB

# %%
import duckdb

# %%
query = """
select month
from df
group by month
"""

result = duckdb.query(query).to_df()

result
# Out:
#      month
# 0  2025-08

# %%
import snowflake.connector

conn = snowflake.connector.connect(
    user='dbt',
    password= 'dbtPassword123',
    account='sskjybh-yw79994',          # e.g., xy12345.us-east-1
    warehouse='COMPUTE_WH',
    database='GA_ANALYTICS',
    schema='GA_EXPORT'
)

cursor = conn.cursor()
# Out:
# 2025-10-31 20:31:46,951 [INFO] Snowflake Connector for Python Version: 4.0.0, Python Version: 3.12.12, Platform: macOS-14.6-arm64-arm-64bit
# 2025-10-31 20:31:46,952 [INFO] Connecting to GLOBAL Snowflake domain

# %%
df.to_csv("all_crimes.csv", index=False)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 2
#       1 import plotly.express as px
# ----> 2 print(px.__version__)
#
# AttributeError: module 'plotly.express' has no attribute '__version__'
